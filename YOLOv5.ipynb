# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
# !unzip -q "/content/images.zip" -d "/content/images"

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/images/images/test/images/*.jpg/
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/images/images/test/images/*.jpg/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/54 /content/images/images/test/images/145_jpg.rf.6281fd727e2e3c30c0ec1ac21d5f0bf9.jpg: 640x640 1 QR, Done. (0.033s)
# image 2/54 /content/images/images/test/images/1DBarcode001_jpg.rf.5382dfc4eaffaa076ac36e5cf04a1a17.jpg: 640x640 1 barcode, Done. (0.032s)
# ...

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-204-gf43cd53 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
